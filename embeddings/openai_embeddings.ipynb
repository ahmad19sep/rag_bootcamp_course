# %%
from langchain_openai import OpenAIEmbeddings

# %%
sentence="Hi my name is ahmad"
embeddings=OpenAIEmbeddings()
embeddings.embed_query(sentence)
# Out:
# [-0.02157926745712757,
#  0.005362988915294409,
#  -0.025653228163719177,
#  -0.03220976144075394,
#  -0.03170051425695419,
#  0.035519856959581375,
#  -0.01202455349266529,
#  -0.016614126041531563,
#  -0.007441346067935228,
#  -0.007683237548917532,
#  0.03070748783648014,
#  0.010293119587004185,
#  0.0027069568168371916,
#  -0.010324947535991669,
#  -0.019402243196964264,
#  -0.026429828256368637,
#  0.023310700431466103,
#  -0.014284328557550907,
#  -0.0024825704749673605,
#  0.009917550720274448,
#  -0.004710518289357424,
#  -0.010312216356396675,
#  0.00888632982969284,
#  -0.0010511139407753944,
#  0.0016518642660230398,
#  0.0013184677809476852,
#  0.012126401998102665,
#  -0.013545922935009003,
#  0.009936647489666939,
#  -0.04636677727103233,
#  0.004315853584557772,
#  -0.01219642348587513,
#  -0.019262200221419334,
#  -0.02640436589717865,
#  -0.0018014550441876054,
#  -0.012565625831484795,
#  -0.0036474689841270447,
#  -0.012832979671657085,
#  0.026989998295903206,
# ...
